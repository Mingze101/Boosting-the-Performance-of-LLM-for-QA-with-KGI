# %% [markdown]
# ** *This file requires uploading two basic files: "0entities_list_update.xlsx" and "0relationships_list_update.xlsx". The other files are process files and do not need to be uploaded. It is currently the most comprehensive version. **

# %% [markdown]
# # Requirements

# %%
# !pip install rdflib
# !python -m spacy download en_core_web_lg
# Out:
# Collecting rdflib
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 3.8 MB/s eta 0:00:00
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.1 rdflib-7.0.0
# 2024-01-23 18:42:37.124254: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-23 18:42:38.096009: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-23 18:42:38.097207: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-23 18:42:39.422241: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-md==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.6.0/en_core_web_md-3.6.0-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-md==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.1.3)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# 2024-01-23 18:43:01.026561: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-23 18:43:01.098144: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-23 18:43:01.098961: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-23 18:43:02.449079: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-lg==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.6.0/en_core_web_lg-3.6.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.1.3)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import pandas as pd
import spacy
import re
from spacy.language import Language
from spacy.tokens import Span
from rdflib import URIRef

# %% [markdown]
# # Named Entity Recognition and Relationship Identification

# %%
# List of texts to be processed
texts = [
    'Who is working in the Computational Materials Science field?',
    'What are the research projects associated to EMMO?',
    'Who are the contributors of the data "datasets"?',
    'Who is working with Researcher "Ebrahim Norouzi" in the same group?',
    'Who is the email address of "ParaView"?',
    'What are the affiliations of Volker Hofmann?',
    'What is "Molecular Dynamics" Software? List the programming language, documentation page, repository, and license information.',
    'What are pre- and post-processing tools for MD simulations?',
    'What are some workflow environments for computational materials science?',
    'How should I cite pyiron?',
    'Where can I find a list of interatomic potentials?',
    'What are python libraries used for calculating local atomic structural environment?',
    'What are the electronic lab notebooks available?',
    'What are the software for Molecular Dynamics (MD)?',
    'What are the ontologies in nanomaterials domain?',
    'What is DAMASK?',
    'What are the data portals for materials science ontologies?',
    'What are the instruments for APT?',
    'In which institution can I find tomography equipment?',
    'What are the educational resources for Ontology?',
    'What is the API of Materials Project?',
    'Which simulation software have a python API?',
    'What is the documentation of the "MatDB Online"?',
    'What are the types of software licenses?',
    'What are the software used to produce the data in the Materials Cloud repository?',
    'What are datasets produced by the BAM organization?',
    'What are some available datasets of mechanical properties of steels?',
    'What are datasets related to "Transmission electron microscopy"?',
    'What is the license of the dataset "Elastic Constant Demo Data"?',
    'What is the repository for "BAM reference data"?',
    'What are the different data formats in the "BAM reference data"?',
    'What is the software version of "pacemaker"?',
    'What is the field of research "BAM reference data"?',
    'What is the description of the "BAM reference data"?',
    'What are the datasets produced in 2022?',
    'Who are the creators of the "BAM reference data"?',
    'What are the datasets published by "BAM"?'
]

# %%
# Regular expression to match content within quotes
pattern = r'"(.*?)"'

# Use the @Language.component decorator to define a pipeline component
@spacy.Language.component("quote_extractor")
def custom_component(doc):
    matches = re.finditer(pattern, doc.text)
    new_ents = []
    for match in matches:
        start, end = match.span()
        span = doc.char_span(start + 1, end - 1, label="QUOTED_TEXT")  # +1 and -1 to remove the quotes
        if span is not None:
            # Check for overlap with existing entities
            overlap = any(span.start < ent.end and span.end > ent.start for ent in doc.ents)
            if not overlap:
                new_ents.append(span)
    doc.ents = list(doc.ents) + new_ents
    return doc

# Load the English model
nlp = spacy.load("en_core_web_sm")  # small model is enough

# Add the custom component to the pipeline
nlp.add_pipe("quote_extractor", before="ner")  # before is logical

# New function to find the adj-noun phrase to as an entity
def find_adjacent_noun_phrases(doc):
    """Extracts individual phrases composed of adjacent nouns, including a preceding adjective if present."""
    noun_phrases = []
    current_phrase = []

    for i, token in enumerate(doc):
        if token.pos_ in ['NOUN', 'PROPN']:  # Check for nouns or proper nouns
            if current_phrase and doc[i-1].pos_ not in ['NOUN', 'PROPN', 'ADJ']:
                # If the current phrase is not empty and the previous token is not a noun, proper noun, or adjective, add the phrase to the list
                noun_phrases.append(' '.join(current_phrase))
                current_phrase = []  # Reset the current phrase

            if i > 0 and doc[i-1].pos_ == 'ADJ':  # Check if the previous word is an adjective
                current_phrase.append(doc[i-1].text + ' ' + token.text)  # Add adjective and noun together
            else:
                current_phrase.append(token.text)  # Add noun
        else:
            if current_phrase:
                noun_phrases.append(' '.join(current_phrase))  # If the current phrase is not empty, add it to the list
                current_phrase = []  # Reset the current phrase

    if current_phrase:  # Ensure the last phrase is added
        noun_phrases.append(' '.join(current_phrase))

    return noun_phrases


# Function to extract both named entities and predicate verbs
def extract_entities_and_verbs(text):
    doc = nlp(text)

    # Entity Extraction
    named_entities = [ent.text for ent in doc.ents]

    # If named_entities is empty, search for phrases between prepositions and question marks
    if not named_entities:
        phrase = find_prep_to_question_phrase(doc)
        if phrase:
            named_entities = [phrase]
        else:
            # Use adjacent noun phrases as a fallback
            adjacent_nouns = find_adjacent_noun_phrases(doc)
            if adjacent_nouns:
                # Flatten the list of adjacent noun phrases
                named_entities = [phrase for phrase in adjacent_nouns]

    # Predicate Verb Extraction
    predicate_verbs = process_text(text)

    return named_entities, predicate_verbs

# Function to process each text
def process_text(text):
    doc = nlp(text)

    # Attributes Extraction
    predicate_verbs = []

    # Function to convert verbs to their lemma form
    def convert_to_lemma(verb):
        return verb.lemma_

    # Function to convert nouns to their singular form
    def convert_to_singular_noun(noun):
        if noun.tag_ == 'NNS':  # Check if it's a plural noun
            return noun.lemma_
        else:
            return noun.text

    # First, look for phrases between 'be' and prepositions
    for token in doc:
        # Looking for phrases between 'be' and prepositions
        if token.lemma_ == "be":
            phrase = []
            preposition_found = False
            for next_token in doc[token.i + 1:]:
                if next_token.pos_ == "ADP":  # Stop at a preposition
                    preposition_found = True
                    break
                phrase.append(next_token)
            # Only add the phrase if it is not empty and preposition is found
            if phrase and preposition_found:
                predicate_verbs.extend([convert_to_lemma(word) if word.pos_ == "VERB" else convert_to_singular_noun(word) for word in phrase])
                break  # Exit the loop if a phrase is found

    # Check if there are lists and use the words after lists as predicate_verbs
    for token in doc:
        if token.text.lower() == "list":
            list_start_index = token.i
            for next_token in doc[token.i + 1:]:
                if next_token.text == ".":
                    predicate_verbs.extend([convert_to_lemma(word) if word.pos_ == "VERB" else convert_to_singular_noun(word) for word in doc[list_start_index + 1:next_token.i]])
                    list_start_index = next_token.i
                    if next_token.text == ".":
                        break
    # Remove 'the' from predicate_verbs
    predicate_verbs = [' '.join([word for word in phrase.split() if word.lower() != "the"]) for phrase in predicate_verbs]

    # Convert predicate_verbs to string format
    predicate_verbs_string = ' '.join(predicate_verbs)

    # Check for 'is' and 'are' and add 'type' and 'description'
    if not predicate_verbs:
        for token in doc:
            if token.lemma_ == "be" and (token.text.lower() == "is" or token.text.lower() == "are"):
                predicate_verbs.extend(["type"])
                break

    # If no phrases found, then look for other verbs
    if not predicate_verbs:
        for token in doc:
            if "VB" in token.tag_ and token.lemma_ not in ["have", "be", "find"]:
                predicate_verbs.append(token.lemma_)

     # If no phrases found, then look for description
    if not predicate_verbs:
       predicate_verbs.append("description")


    return predicate_verbs

# New function to find the part between the preposition and the question mark
def find_prep_to_question_phrase(doc):
    phrase = []
    verb_found = False
    for token in doc:
        if token.pos_ == "ADP":  # If the token is a preposition (ADP)
            for next_token in doc[token.i + 1:]:  # Iterate over following tokens
                if next_token.text == "?":  # Stop if a question mark is found
                    break
                if next_token.pos_ == "VERB":  # Check if the token is a verb
                    verb_found = True
                    break  # Break if a verb is found
                phrase.append(next_token.text)  # Append the token text to the phrase list
            break  # Stop after finding the first preposition

    return '' if verb_found else ' '.join(phrase)  # Return an empty string if a verb is found, else return the phrase



# Create a list of dataframes to concatenate
dfs = []

# Process each text and store the results in a list of dataframes
for text in texts:
    named_entities, predicate_verbs = extract_entities_and_verbs(text)
    # Flatten the named_entities if it contains lists and then join
    flattened_entities = [item for sublist in named_entities for item in (sublist if isinstance(sublist, list) else [sublist])]
    df_row = pd.DataFrame({
        "Text": [text],
        "Named Entities": [','.join(flattened_entities)],
        "Predicate Verbs": [' '.join(predicate_verbs)]
    })
    dfs.append(df_row)

# Concatenate the dataframes in the list
df = pd.concat(dfs, ignore_index=True)

# # Save the DataFrame to an Excel file
df.to_excel("1QustionEntityandRelationship.xlsx", index=False)

df
# Out:
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6                        Molecular Dynamics
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish

# %% [markdown]
# # Find 5 or 10 Most Similarest Entities

# %%
def find_most_similar_entities(df, entity_column):
    # Load the spaCy English model
    nlp = spacy.load("en_core_web_lg") # small model: low accuracy; large model: do best
    # Read data from an Excel file
    df_entity = pd.read_excel('0entities_list_update.xlsx')

    # Function to extract abbreviation
    def extract_abbreviation(text):
        if isinstance(text, str):
            match = re.search(r'\(([^)]+)\)', text)
            return match.group(1) if match else text
        else:
            return text

    # Apply the function to extract abbreviations
    df_entity['entity_abb'] = df_entity['entity_readable'].apply(extract_abbreviation)

    # Convert to lowercase
    df_entity['entity_lowercase'] = df_entity['entity_abb'].str.lower()

    # Function to find most similar entities
    def process_entity(question_entity):
        question_word = nlp(question_entity.lower())
        similarity_scores = {}

        # Set a similarity threshold
        threshold = 0.6

        for index, row in df_entity.iterrows():
            if pd.isna(row['entity_lowercase']):
                continue

            kd_word = nlp(row['entity_lowercase'])
            similarity = question_word.similarity(kd_word)
            if similarity > threshold:
                similarity_scores[index] = similarity

        # # Find the top 10 highest similarity scores
        # top_10_similarities = sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True)[:10]

        # if top_10_similarities:
        #     similar_entities = [df_entity.at[index, 'entity_readable'] for index, _ in top_10_similarities]
        #     entity_uris = [df_entity.at[index, 'entity_uri'] for index, _ in top_10_similarities]

        # Find the top 5 highest similarity scores
        top_5_similarities = sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True)[:5]

        if top_5_similarities:
            similar_entities = [df_entity.at[index, 'entity_readable'] for index, _ in top_5_similarities]
            entity_uris = [df_entity.at[index, 'entity_uri'] for index, _ in top_5_similarities]

            return similar_entities, entity_uris
        else:
            return None, None

    # Function to process a list of entities separated by commas
    def process_entity_list(entity_list):
        similar_entities_list = []
        entity_uris_list = []

        for entity in entity_list.split(','):
            entity = entity.strip()
            if entity:
                similar_entities, entity_uris = process_entity(entity)
                if similar_entities and entity_uris:
                    similar_entities_list.extend(similar_entities)
                    entity_uris_list.extend(entity_uris)

        if similar_entities_list:
            return similar_entities_list, entity_uris_list
        else:
            return None, None


    # Apply to each entity in the provided column of df
    results = df[entity_column].apply(lambda x: process_entity(x) if isinstance(x, str) and ',' not in x else process_entity_list(x) if isinstance(x, str) else (None, None))
    # results = df[entity_column].apply(lambda x: process_entity(x))
    df['Similar Entities'] = results.apply(lambda x: x[0] if x else None)
    df['Entity URIs'] = results.apply(lambda x: x[1] if x else None)
    return df

# df = pd.read_excel("1QustionEntityandRelationship.xlsx")
# Assuming df is your DataFrame with a column 'Named Entities'
df = find_most_similar_entities(df, 'Named Entities')

# Save the DataFrame to an Excel file
df.to_excel("2SimilarEntities5.xlsx", index=False)

df
# Out:
# <ipython-input-29-3d083fb1e707>:34: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = question_word.similarity(kd_word)
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6                        Molecular Dynamics
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                      Similar Entities  \
# 0   [Computational materials science, Computationa...
# 1   [Elemental Multiperspective Material Ontology ...
# 2   [datasets, dataset, data analysis, Materials D...
# 3                  [Ebrahim Norouzi, Ebrahim Norouzi]
# 4                      [paraview, ParaView, ParaView]
# 5                                    [Volker Hofmann]
# 6   [molecular dynamics, Carr Parrinello Molecular...
# 7   [Molecular Dynamics (MD), Dr Sarath Menon, Tho...
# 8   [Computational materials science, Computationa...
# 9                                            [Pyiron]
# 10  [potentials repository, Discrete element simul...
# 11  [Python scripts, python, Python, Python, OPTIM...
# 12  [electronic lab notebook, Jupyter lab, Laborat...
# 13  [molecular dynamics, Carr Parrinello Molecular...
# 14  [Topological Material Database, HybriD³ materi...
# 15                                               None
# 16  [Materials Science, Computational materials sc...
# 17                                               None
# 18  [organization, Organization, organization, fun...
# 19  [ontology, eNanoMapper ontology, ontology repo...
# 20  [funding project of, funding project of, mecha...
# 21                [Kim API, JSON, Github, Java, Java]
# 22  [MatDB Online, Virtual materials Marketplace, ...
# 23  [Proprietary commercial software license, Prop...
# 24  [The Open Quantum Materials Database, The Visu...
# 25  [Bundesanstalt für Materialforschung und -prüf...
# 26  [mechanics of materials, Mechanics of Material...
# 27  [Transmission electron microscopy, Confocal mi...
# 28  [Elastic Constant Demo Data, hardness data, Pr...
# 29  [data analysis, HDF5 data, Topological data an...
# 30  [data analysis, HDF5 data, Topological data an...
# 31                                        [pacemaker]
# 32  [data analysis, HDF5 data, Topological data an...
# 33  [data analysis, HDF5 data, Topological data an...
# 34  [De Geest, P., Droesbeke, B., Eguinoa, I., Gai...
# 35  [data analysis, HDF5 data, Topological data an...
# 36  [Bundesanstalt für Materialforschung und -prüf...
#
#                                           Entity URIs
# 0   [http://demo.fiz-karlsruhe.de/matwerk/E49517, ...
# 1     [http://demo.fiz-karlsruhe.de/matwerk/E1126751]
# 2   [http://demo.fiz-karlsruhe.de/matwerk/E1172216...
# 3   [http://demo.fiz-karlsruhe.de/matwerk/E15879, ...
# 4   [http://demo.fiz-karlsruhe.de/matwerk/E1231097...
# 5          [http://www.wikidata.org/entity/Q84561074]
# 6   [http://demo.fiz-karlsruhe.de/matwerk/E616496,...
# 7   [http://demo.fiz-karlsruhe.de/matwerk/E61379, ...
# 8   [http://demo.fiz-karlsruhe.de/matwerk/E49517, ...
# 9      [http://demo.fiz-karlsruhe.de/matwerk/E457491]
# 10  [http://purls.helmholtz-metadaten.de/mwo/Poten...
# 11  [http://demo.fiz-karlsruhe.de/matwerk/E1198379...
# 12  [http://purls.helmholtz-metadaten.de/mwo/Elect...
# 13  [http://demo.fiz-karlsruhe.de/matwerk/E616496,...
# 14  [http://demo.fiz-karlsruhe.de/matwerk/E1077779...
# 15                                               None
# 16  [http://demo.fiz-karlsruhe.de/matwerk/E1245665...
# 17                                               None
# 18  [http://nfdi.fiz-karlsruhe.de/ontology/Organiz...
# 19  [https://nfdi.fiz-karlsruhe.de/ontology/Ontolo...
# 20  [https://nfdi.fiz-karlsruhe.de/ontology/fundin...
# 21  [http://demo.fiz-karlsruhe.de/matwerk/E534029,...
# 22  [http://demo.fiz-karlsruhe.de/matwerk/E1146342...
# 23  [http://www.ebi.ac.uk/swo/license/SWO_1000002,...
# 24  [http://demo.fiz-karlsruhe.de/matwerk/E1037081...
# 25  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...
# 26  [http://demo.fiz-karlsruhe.de/matwerk/E54629, ...
# 27  [http://demo.fiz-karlsruhe.de/matwerk/E625404,...
# 28  [http://demo.fiz-karlsruhe.de/matwerk/E1247418...
# 29  [http://demo.fiz-karlsruhe.de/matwerk/E68897, ...
# 30  [http://demo.fiz-karlsruhe.de/matwerk/E68897, ...
# 31     [http://demo.fiz-karlsruhe.de/matwerk/E511556]
# 32  [http://demo.fiz-karlsruhe.de/matwerk/E68897, ...
# 33  [http://demo.fiz-karlsruhe.de/matwerk/E68897, ...
# 34  [http://demo.fiz-karlsruhe.de/matwerk/E964967,...
# 35  [http://demo.fiz-karlsruhe.de/matwerk/E68897, ...
# 36  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...

# %% [markdown]
# If there are none in similar units, use the small model isntead of large model

# %%
def find_most_similar_entities(df, entity_column):
    # Load the spaCy English model
    nlp = spacy.load("en_core_web_sm") #small model: do much better when large model fails
    # Read data from an Excel file
    df_entity = pd.read_excel('0entities_list_update.xlsx')

    # Function to extract abbreviation
    def extract_abbreviation(text):
        if isinstance(text, str):
            match = re.search(r'\(([^)]+)\)', text)
            return match.group(1) if match else text
        else:
            return text

    # Apply the function to extract abbreviations
    df_entity['entity_abb'] = df_entity['entity_readable'].apply(extract_abbreviation)

    # Convert to lowercase
    df_entity['entity_lowercase'] = df_entity['entity_abb'].str.lower()

    # Function to find most similar entities
    def process_entity(question_entity):
        question_word = nlp(question_entity.lower())
        similarity_scores = {}

        # Set a similarity threshold
        threshold = 0.6

        for index, row in df_entity.iterrows():
            if pd.isna(row['entity_lowercase']):
                continue

            kd_word = nlp(row['entity_lowercase'])
            similarity = question_word.similarity(kd_word)
            if similarity > threshold:
                similarity_scores[index] = similarity


        # # Find the top 10 highest similarity scores
        # top_10_similarities = sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True)[:10]

        # if top_10_similarities:
        #     similar_entities = [df_entity.at[index, 'entity_readable'] for index, _ in top_10_similarities]
        #     entity_uris = [df_entity.at[index, 'entity_uri'] for index, _ in top_10_similarities]

        # Find the top 5 highest similarity scores
        top_5_similarities = sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True)[:5]
        print(top_5_similarities)

        if top_5_similarities:
            similar_entities = [df_entity.at[index, 'entity_readable'] for index, _ in top_5_similarities]
            entity_uris = [df_entity.at[index, 'entity_uri'] for index, _ in top_5_similarities]

            return similar_entities, entity_uris
        else:
            return None, None

    # Function to process a list of entities separated by commas
    def process_entity_list(entity_list):
        similar_entities_list = []
        entity_uris_list = []

        for entity in entity_list.split(','):
            entity = entity.strip()
            if entity:
                similar_entities, entity_uris = process_entity(entity)
                if similar_entities and entity_uris:
                    similar_entities_list.extend(similar_entities)
                    entity_uris_list.extend(entity_uris)

        if similar_entities_list:
            return similar_entities_list, entity_uris_list
        else:
            return None, None


    # Apply to each entity in the provided column of df
    results = df[entity_column].apply(lambda x: process_entity(x) if isinstance(x, str) and ',' not in x else process_entity_list(x) if isinstance(x, str) else (None, None))
    # results = df[entity_column].apply(lambda x: process_entity(x))
    df['Similar Entities'] = results.apply(lambda x: x[0] if x else None)
    df['Entity URIs'] = results.apply(lambda x: x[1] if x else None)
    return df

# Assuming df is your DataFrame with a column 'Named Entities'
df_null = find_most_similar_entities(df[df['Similar Entities'].isnull()], 'Named Entities')


df[df.isnull()] = df_null[df.isnull()]

# Save the DataFrame to an Excel file
df.to_excel("2SimilarEntities5_up.xlsx", index=False)

df
# Out:
# <ipython-input-38-f0ea5d2ed95d>:34: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = question_word.similarity(kd_word)
# [(1152, 0.826565392591856), (724, 0.8210707129094054), (725, 0.8210707129094054), (1062, 0.8004280163819343), (551, 0.7958029372285703)]
# [(517, 0.7153859273686815), (18, 0.7139619803978803), (847, 0.6803068597187358), (1831, 0.6719893294018098), (1522, 0.655508816938155)]
# <ipython-input-38-f0ea5d2ed95d>:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Similar Entities'] = results.apply(lambda x: x[0] if x else None)
# <ipython-input-38-f0ea5d2ed95d>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Entity URIs'] = results.apply(lambda x: x[1] if x else None)
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6                        Molecular Dynamics
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                      Similar Entities  \
# 0   [Computational materials science, Computationa...
# 1   [Elemental Multiperspective Material Ontology ...
# 2   [datasets, dataset, data analysis, Materials D...
# 3                  [Ebrahim Norouzi, Ebrahim Norouzi]
# 4                      [paraview, ParaView, ParaView]
# 5                                    [Volker Hofmann]
# 6   [molecular dynamics, Carr Parrinello Molecular...
# 7   [Molecular Dynamics (MD), Dr Sarath Menon, Tho...
# 8   [Computational materials science, Computationa...
# 9                                            [Pyiron]
# 10  [potentials repository, Discrete element simul...
# 11  [Python scripts, python, Python, Python, OPTIM...
# 12  [electronic lab notebook, Jupyter lab, Laborat...
# 13  [molecular dynamics, Carr Parrinello Molecular...
# 14  [Topological Material Database, HybriD³ materi...
# 15  [https://github.com/eisenforschung/damask, Jmo...
# 16  [Materials Science, Computational materials sc...
# 17  [MuPIF, WP OMS-1.1 Support foundation and mana...
# 18  [organization, Organization, organization, fun...
# 19  [ontology, eNanoMapper ontology, ontology repo...
# 20  [funding project of, funding project of, mecha...
# 21                [Kim API, JSON, Github, Java, Java]
# 22  [MatDB Online, Virtual materials Marketplace, ...
# 23  [Proprietary commercial software license, Prop...
# 24  [The Open Quantum Materials Database, The Visu...
# 25  [Bundesanstalt für Materialforschung und -prüf...
# 26  [mechanics of materials, Mechanics of Material...
# 27  [Transmission electron microscopy, Confocal mi...
# 28  [Elastic Constant Demo Data, hardness data, Pr...
# 29  [data analysis, HDF5 data, Topological data an...
# 30  [data analysis, HDF5 data, Topological data an...
# 31                                        [pacemaker]
# 32  [data analysis, HDF5 data, Topological data an...
# 33  [data analysis, HDF5 data, Topological data an...
# 34  [De Geest, P., Droesbeke, B., Eguinoa, I., Gai...
# 35  [data analysis, HDF5 data, Topological data an...
# 36  [Bundesanstalt für Materialforschung und -prüf...
#
#                                           Entity URIs
# 0   [http://demo.fiz-karlsruhe.de/matwerk/E49517, ...
# 1     [http://demo.fiz-karlsruhe.de/matwerk/E1126751]
# 2   [http://demo.fiz-karlsruhe.de/matwerk/E1172216...
# 3   [http://demo.fiz-karlsruhe.de/matwerk/E15879, ...
# 4   [http://demo.fiz-karlsruhe.de/matwerk/E1231097...
# 5          [http://www.wikidata.org/entity/Q84561074]
# 6   [http://demo.fiz-karlsruhe.de/matwerk/E616496,...
# 7   [http://demo.fiz-karlsruhe.de/matwerk/E61379, ...
# 8   [http://demo.fiz-karlsruhe.de/matwerk/E49517, ...
# 9      [http://demo.fiz-karlsruhe.de/matwerk/E457491]
# 10  [http://purls.helmholtz-metadaten.de/mwo/Poten...
# 11  [http://demo.fiz-karlsruhe.de/matwerk/E1198379...
# 12  [http://purls.helmholtz-metadaten.de/mwo/Elect...
# 13  [http://demo.fiz-karlsruhe.de/matwerk/E616496,...
# 14  [http://demo.fiz-karlsruhe.de/matwerk/E1077779...
# 15  [http://demo.fiz-karlsruhe.de/matwerk/E176529,...
# 16  [http://demo.fiz-karlsruhe.de/matwerk/E1245665...
# 17  [http://demo.fiz-karlsruhe.de/matwerk/E513579,...
# 18  [http://nfdi.fiz-karlsruhe.de/ontology/Organiz...
# 19  [https://nfdi.fiz-karlsruhe.de/ontology/Ontolo...
# 20  [https://nfdi.fiz-karlsruhe.de/ontology/fundin...
# 21  [http://demo.fiz-karlsruhe.de/matwerk/E534029,...
# 22  [http://demo.fiz-karlsruhe.de/matwerk/E1146342...
# 23  [http://www.ebi.ac.uk/swo/license/SWO_1000002,...
# 24  [http://demo.fiz-karlsruhe.de/matwerk/E1037081...
# 25  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...
# 26  [http://demo.fiz-karlsruhe.de/matwerk/E54629, ...
# 27  [http://demo.fiz-karlsruhe.de/matwerk/E625404,...
# 28  [http://demo.fiz-karlsruhe.de/matwerk/E1247418...
# 29  [http://demo.fiz-karlsruhe.de/matwerk/E68897, ...
# 30  [http://demo.fiz-karlsruhe.de/matwerk/E68897, ...
# 31     [http://demo.fiz-karlsruhe.de/matwerk/E511556]
# 32  [http://demo.fiz-karlsruhe.de/matwerk/E68897, ...
# 33  [http://demo.fiz-karlsruhe.de/matwerk/E68897, ...
# 34  [http://demo.fiz-karlsruhe.de/matwerk/E964967,...
# 35  [http://demo.fiz-karlsruhe.de/matwerk/E68897, ...
# 36  [http://demo.fiz-karlsruhe.de/matwerk/E1247968...

# %% [markdown]
# # Find 10 Most Similarest Relationships and added "description"

# %%
import pandas as pd
import spacy
from rdflib import URIRef
import re

def find_most_similar_relationships(df, relationship_column):
    # Load the spaCy English model
    nlp = spacy.load("en_core_web_lg")

    # Read data from an Excel file
    df_relationship = pd.read_excel('0relationships_list_update.xlsx')

    # Convert the second column to lowercase and save it in a new column 'entity_lowercase'
    df_relationship['relationship_lowercase'] = df_relationship['relationship_readable'].str.lower()

    # Define a function to remove specific words and plural 's'
    def preprocess_text(text):
        # Remove specific words
        words_to_remove = {'has', 'is', 'of', 'in'}
        tokens = text.split()
        tokens = [word for word in tokens if word not in words_to_remove]

        # Remove trailing 's' for plurals
        processed_text = ' '.join(tokens)
        if processed_text.endswith('s'):
            processed_text = processed_text[:-1]

        return processed_text

    # Apply preprocessing to 'relationship_lowercase'
    df_relationship['cleaned_relationship'] = df_relationship['relationship_lowercase'].apply(preprocess_text)

    # Function to find most similar relationships
    def process_relationship(question_relationship):
        if not isinstance(question_relationship, str):
            return None, None, None

        question_word = nlp(preprocess_text(question_relationship.lower()))

        # Initialize a dictionary to store similarity scores
        similarity_scores = {}

        # Set a similarity threshold
        threshold = 0.6

        # Iterate through each word in the dataset and calculate its similarity to word1
        for index, row in df_relationship.iterrows():
            # Skip if the word is NaN
            if pd.isna(row['cleaned_relationship']):
                continue

            word2 = nlp(row['cleaned_relationship'])
            similarity = question_word.similarity(word2)
            similarity_scores[index] = similarity

            # Only store words with similarity scores above the threshold
            if similarity >= threshold:
                similarity_scores[index] = similarity

        # Find the top 10 highest similarity scores
        top_10_similarities = sorted(similarity_scores.items(), key=lambda x: x[1], reverse=True)[:10]

        similar_relationships = []
        relationship_uris = []
        relationship_uris_withNS = []

        for index, similarity_score in top_10_similarities:
            if 0 <= index < len(df_relationship):
                similar_relationships.append(df_relationship.at[index, 'relationship_readable'])
                relationship_uris.append(df_relationship.at[index, 'relationship_uri'])
                relationship_uris_withNS.append(df_relationship.at[index, 'Predicate with NS'])
        if 'mwo:description' not in relationship_uris_withNS:
          relationship_uris_withNS.append('mwo:description')
        if 'dcterms:description' not in relationship_uris_withNS:
          relationship_uris_withNS.append('dcterms:description')

        return similar_relationships, relationship_uris, relationship_uris_withNS

    # Apply to each entity in the provided column of df
    results = df[relationship_column].apply(lambda x: process_relationship(x))
    df['Similar Relationships'] = results.apply(lambda x: x[0] if x else None)
    df['Relationship URIs'] = results.apply(lambda x: x[1] if x else None)
    df['relationship_uris_withNS'] = results.apply(lambda x: x[2] if x else None)

    return df

df = pd.read_excel("2SimilarEntities5_up.xlsx")
# Example usage with a DataFrame 'df' and a column 'Named Relationships'
df = find_most_similar_relationships(df, 'Predicate Verbs')

# To save the modified DataFrame:
df.to_excel("4beforeSparq5X10.xlsx", index=False)
df
# Out:
# <ipython-input-81-2bee4a338292>:53: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarity = question_word.similarity(word2)
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# 16  What are the data portals for materials scienc...
# 17                  What are the instruments for APT?
# 18  In which institution can I find tomography equ...
# 19   What are the educational resources for Ontology?
# 20              What is the API of Materials Project?
# 21       Which simulation software have a python API?
# 22   What is the documentation of the "MatDB Online"?
# 23           What are the types of software licenses?
# 24  What are the software used to produce the data...
# 25  What are datasets produced by the BAM organiza...
# 26  What are some available datasets of mechanical...
# 27  What are datasets related to "Transmission ele...
# 28  What is the license of the dataset "Elastic Co...
# 29   What is the repository for "BAM reference data"?
# 30  What are the different data formats in the "BA...
# 31       What is the software version of "pacemaker"?
# 32  What is the field of research "BAM reference d...
# 33  What is the description of the "BAM reference ...
# 34            What are the datasets produced in 2022?
# 35  Who are the creators of the "BAM reference data"?
# 36          What are the datasets published by "BAM"?
#
#                              Named Entities  \
# 0       the Computational Materials Science
# 1                                      EMMO
# 2                                  datasets
# 3                           Ebrahim Norouzi
# 4                                  ParaView
# 5                            Volker Hofmann
# 6                        Molecular Dynamics
# 7                                        MD
# 8           computational materials science
# 9                                    pyiron
# 10                   interatomic potentials
# 11  python libraries,structural environment
# 12                 electronic lab notebooks
# 13                    Molecular Dynamics,MD
# 14                     nanomaterials domain
# 15                                   DAMASK
# 16             materials science ontologies
# 17                                      APT
# 18         institution,tomography equipment
# 19                                 Ontology
# 20             the API of Materials Project
# 21                                      API
# 22                             MatDB Online
# 23                        software licenses
# 24                      the Materials Cloud
# 25                                      BAM
# 26          mechanical properties of steels
# 27         Transmission electron microscopy
# 28               Elastic Constant Demo Data
# 29                       BAM reference data
# 30                       BAM reference data
# 31                                pacemaker
# 32                       BAM reference data
# 33                       BAM reference data
# 34                                     2022
# 35                       BAM reference data
# 36                                      BAM
#
#                                       Predicate Verbs  \
# 0                                                work
# 1                          research project associate
# 2                                         contributor
# 3                                                work
# 4                                       email address
# 5                                         affiliation
# 6    programming language , documentation page , r...
# 7                     pre- and post - processing tool
# 8                           some workflow environment
# 9                                                cite
# 10                                        description
# 11                                 python library use
# 12                                               type
# 13                                           software
# 14                                           ontology
# 15                                               type
# 16                                       datum portal
# 17                                         instrument
# 18                                        description
# 19                               educational resource
# 20                                                API
# 21                                        description
# 22                                      documentation
# 23                                               type
# 24                     software use to produce  datum
# 25                                    dataset produce
# 26                             some available dataset
# 27                                     dataset relate
# 28                                            license
# 29                                         repository
# 30                              different data format
# 31                                   software version
# 32                                              field
# 33                                        description
# 34                                    dataset produce
# 35                                            creator
# 36                                    dataset publish
#
#                                      Similar Entities  \
# 0   ['Computational materials science', 'Computati...
# 1   ['Elemental Multiperspective Material Ontology...
# 2   ['datasets', 'dataset', 'data analysis', 'Mate...
# 3              ['Ebrahim Norouzi', 'Ebrahim Norouzi']
# 4                ['paraview', 'ParaView', 'ParaView']
# 5                                  ['Volker Hofmann']
# 6   ['molecular dynamics', 'Carr Parrinello Molecu...
# 7   ['Molecular Dynamics (MD)', 'Dr Sarath Menon',...
# 8   ['Computational materials science', 'Computati...
# 9                                          ['Pyiron']
# 10  ['potentials repository', 'Discrete element si...
# 11  ['Python scripts', 'python', 'Python', 'Python...
# 12  ['electronic lab notebook', 'Jupyter lab', 'La...
# 13  ['molecular dynamics', 'Carr Parrinello Molecu...
# 14  ['Topological Material Database', 'HybriD³ mat...
# 15  ['https://github.com/eisenforschung/damask', '...
# 16  ['Materials Science', 'Computational materials...
# 17  ['MuPIF', 'WP OMS-1.1 Support foundation and m...
# 18  ['organization', 'Organization', 'organization...
# 19  ['ontology', 'eNanoMapper ontology', 'ontology...
# 20  ['funding project of', 'funding project of', '...
# 21      ['Kim API', 'JSON', 'Github', 'Java', 'Java']
# 22  ['MatDB Online', 'Virtual materials Marketplac...
# 23  ['Proprietary commercial software license', 'P...
# 24  ['The Open Quantum Materials Database', 'The V...
# 25  ['Bundesanstalt für Materialforschung und -prü...
# 26  ['mechanics of materials', 'Mechanics of Mater...
# 27  ['Transmission electron microscopy', 'Confocal...
# 28  ['Elastic Constant Demo Data', 'hardness data'...
# 29  ['data analysis', 'HDF5 data', 'Topological da...
# 30  ['data analysis', 'HDF5 data', 'Topological da...
# 31                                      ['pacemaker']
# 32  ['data analysis', 'HDF5 data', 'Topological da...
# 33  ['data analysis', 'HDF5 data', 'Topological da...
# 34  ['De Geest, P., Droesbeke, B., Eguinoa, I., Ga...
# 35  ['data analysis', 'HDF5 data', 'Topological da...
# 36  ['Bundesanstalt für Materialforschung und -prü...
#
#                                           Entity URIs  \
# 0   ['http://demo.fiz-karlsruhe.de/matwerk/E49517'...
# 1   ['http://demo.fiz-karlsruhe.de/matwerk/E1126751']
# 2   ['http://demo.fiz-karlsruhe.de/matwerk/E117221...
# 3   ['http://demo.fiz-karlsruhe.de/matwerk/E15879'...
# 4   ['http://demo.fiz-karlsruhe.de/matwerk/E123109...
# 5        ['http://www.wikidata.org/entity/Q84561074']
# 6   ['http://demo.fiz-karlsruhe.de/matwerk/E616496...
# 7   ['http://demo.fiz-karlsruhe.de/matwerk/E61379'...
# 8   ['http://demo.fiz-karlsruhe.de/matwerk/E49517'...
# 9    ['http://demo.fiz-karlsruhe.de/matwerk/E457491']
# 10  ['http://purls.helmholtz-metadaten.de/mwo/Pote...
# 11  ['http://demo.fiz-karlsruhe.de/matwerk/E119837...
# 12  ['http://purls.helmholtz-metadaten.de/mwo/Elec...
# 13  ['http://demo.fiz-karlsruhe.de/matwerk/E616496...
# 14  ['http://demo.fiz-karlsruhe.de/matwerk/E107777...
# 15  ['http://demo.fiz-karlsruhe.de/matwerk/E176529...
# 16  ['http://demo.fiz-karlsruhe.de/matwerk/E124566...
# 17  ['http://demo.fiz-karlsruhe.de/matwerk/E513579...
# 18  ['http://nfdi.fiz-karlsruhe.de/ontology/Organi...
# 19  ['https://nfdi.fiz-karlsruhe.de/ontology/Ontol...
# 20  ['https://nfdi.fiz-karlsruhe.de/ontology/fundi...
# 21  ['http://demo.fiz-karlsruhe.de/matwerk/E534029...
# 22  ['http://demo.fiz-karlsruhe.de/matwerk/E114634...
# 23  ['http://www.ebi.ac.uk/swo/license/SWO_1000002...
# 24  ['http://demo.fiz-karlsruhe.de/matwerk/E103708...
# 25  ['http://demo.fiz-karlsruhe.de/matwerk/E124796...
# 26  ['http://demo.fiz-karlsruhe.de/matwerk/E54629'...
# 27  ['http://demo.fiz-karlsruhe.de/matwerk/E625404...
# 28  ['http://demo.fiz-karlsruhe.de/matwerk/E124741...
# 29  ['http://demo.fiz-karlsruhe.de/matwerk/E68897'...
# 30  ['http://demo.fiz-karlsruhe.de/matwerk/E68897'...
# 31   ['http://demo.fiz-karlsruhe.de/matwerk/E511556']
# 32  ['http://demo.fiz-karlsruhe.de/matwerk/E68897'...
# 33  ['http://demo.fiz-karlsruhe.de/matwerk/E68897'...
# 34  ['http://demo.fiz-karlsruhe.de/matwerk/E964967...
# 35  ['http://demo.fiz-karlsruhe.de/matwerk/E68897'...
# 36  ['http://demo.fiz-karlsruhe.de/matwerk/E124796...
#
#                                 Similar Relationships  \
# 0   [has work package, has expertise in, has fundi...
# 1   [has related Project, related participant proj...
# 2   [has contributor, related participant project ...
# 3   [has work package, has expertise in, has fundi...
# 4   [has email address , has postal address, has w...
# 5   [has affiliation, has curation status, has par...
# 6   [has documentation, has bibliographic citation...
# 7   [required tool, has related resource, related ...
# 8   [has some values from, has work package, has r...
# 9   [has annotated source , has bibliographic cita...
# 10  [has  description, has description, has biblio...
# 11  [uses software, has example of usage, has repo...
# 12  [has type, has object type, has media type or ...
# 13  [has software, uses software, required tool, h...
# 14  [has ontology, has bibliographic citation, has...
# 15  [has type, has object type, has media type or ...
# 16  [has repository, has website, has definition s...
# 17  [has instrument model, has first element, has ...
# 18  [has  description, has description, has biblio...
# 19  [has related resource, related participant pro...
# 20  [has url, has file Extension, has repository, ...
# 21  [has  description, has description, has biblio...
# 22  [has documentation, has bibliographic citation...
# 23  [has type, has object type, has media type or ...
# 24  [has conforms to specification, belongs to, re...
# 25  [has dataset, has definition source, has annot...
# 26  [has some values from, has related resource, a...
# 27  [has dataset, has related resource, related pa...
# 28  [has license, has license, has affiliation, ha...
# 29  [has repository, has annotated source , has de...
# 30  [has dataset, has format, has format, has docu...
# 31  [has software, has Version, uses software, has...
# 32  [has related task area, has discipline, has ma...
# 33  [has  description, has description, has biblio...
# 34  [has dataset, has definition source, has annot...
# 35  [has creator, has author, has contributor, use...
# 36  [has dataset, has repository, has bibliographi...
#
#                                     Relationship URIs  \
# 0   [http://purls.helmholtz-metadaten.de/mwo/hasWo...
# 1   [http://nfdi.fiz-karlsruhe.de/ontology/related...
# 2   [http://purls.helmholtz-metadaten.de/mwo/hasCo...
# 3   [http://purls.helmholtz-metadaten.de/mwo/hasWo...
# 4   [http://purls.helmholtz-metadaten.de/mwo/email...
# 5   [http://purls.helmholtz-metadaten.de/mwo/hasAf...
# 6   [http://purls.helmholtz-metadaten.de/mwo/hasDo...
# 7   [http://purls.helmholtz-metadaten.de/mwo/requi...
# 8   [http://www.w3.org/2002/07/owl#someValuesFrom,...
# 9   [http://www.w3.org/2002/07/owl#annotatedSource...
# 10  [http://purl.org/dc/terms/description, http://...
# 11  [http://www.ebi.ac.uk/swo/SWO_0000082, http://...
# 12  [http://www.w3.org/1999/02/22-rdf-syntax-ns#ty...
# 13  [https://nfdi.fiz-karlsruhe.de/ontology/Softwa...
# 14  [https://nfdi.fiz-karlsruhe.de/ontology/Ontolo...
# 15  [http://www.w3.org/1999/02/22-rdf-syntax-ns#ty...
# 16  [http://purls.helmholtz-metadaten.de/mwo/hasRe...
# 17  [http://purls.helmholtz-metadaten.de/mwo/instr...
# 18  [http://purl.org/dc/terms/description, http://...
# 19  [http://purls.helmholtz-metadaten.de/mwo/hasRe...
# 20  [http://nfdi.fiz-karlsruhe.de/ontology/url, ht...
# 21  [http://purl.org/dc/terms/description, http://...
# 22  [http://purls.helmholtz-metadaten.de/mwo/hasDo...
# 23  [http://www.w3.org/1999/02/22-rdf-syntax-ns#ty...
# 24  [http://purls.helmholtz-metadaten.de/mwo/confo...
# 25  [https://nfdi.fiz-karlsruhe.de/ontology/Datase...
# 26  [http://www.w3.org/2002/07/owl#someValuesFrom,...
# 27  [https://nfdi.fiz-karlsruhe.de/ontology/Datase...
# 28  [http://www.ebi.ac.uk/swo/has_license, http://...
# 29  [http://purls.helmholtz-metadaten.de/mwo/hasRe...
# 30  [https://nfdi.fiz-karlsruhe.de/ontology/Datase...
# 31  [https://nfdi.fiz-karlsruhe.de/ontology/Softwa...
# 32  [http://purls.helmholtz-metadaten.de/mwo/relat...
# 33  [http://purl.org/dc/terms/description, http://...
# 34  [https://nfdi.fiz-karlsruhe.de/ontology/Datase...
# 35  [http://purls.helmholtz-metadaten.de/mwo/hasCr...
# 36  [https://nfdi.fiz-karlsruhe.de/ontology/Datase...
#
#                              relationship_uris_withNS
# 0   [mwo:hasWorkPackage, mwo:hasExpertiseIn, nfdic...
# 1   [nfdicore:relatedProject, mwo:relatedParticipa...
# 2   [mwo:hasContributor, mwo:relatedParticipantPro...
# 3   [mwo:hasWorkPackage, mwo:hasExpertiseIn, nfdic...
# 4   [mwo:emailAddress, mwo:hasPostalAddress, mwo:h...
# 5   [mwo:hasAffiliation, ns2:IAO_0000114, nfdicore...
# 6   [mwo:hasDocumentation, dcterms:bibliographicCi...
# 7   [mwo:requiredTool, mwo:hasRelatedResource, mwo...
# 8   [owl:someValuesFrom, mwo:hasWorkPackage, mwo:h...
# 9   [owl:annotatedSource, dcterms:bibliographicCit...
# 10  [dcterms:description, mwo:description, dcterms...
# 11  [ns3:SWO_0000082, ns2:IAO_0000112, mwo:hasRepo...
# 12  [rdf:type, nfdicore:objectType, dc:contributor...
# 13  [nfdicore:Software, ns3:SWO_0000082, mwo:requi...
# 14  [nfdicore:Ontology, dcterms:bibliographicCitat...
# 15  [rdf:type, nfdicore:objectType, dc:contributor...
# 16  [mwo:hasRepository, mwo:hasWebsite, ns2:IAO_00...
# 17  [mwo:instrumentModel, rdf:first, mwo:hasDocume...
# 18  [dcterms:description, mwo:description, dcterms...
# 19  [mwo:hasRelatedResource, mwo:relatedParticipan...
# 20  [nfdicore:url, nfdicore:fileExtension, mwo:has...
# 21  [dcterms:description, mwo:description, dcterms...
# 22  [mwo:hasDocumentation, dcterms:bibliographicCi...
# 23  [rdf:type, nfdicore:objectType, dc:contributor...
# 24  [mwo:conformsToSpecification, mwo:belongsTo, m...
# 25  [nfdicore:Dataset, ns2:IAO_0000119, owl:annota...
# 26  [owl:someValuesFrom, mwo:hasRelatedResource, o...
# 27  [nfdicore:Dataset, mwo:hasRelatedResource, mwo...
# 28  [ns3:has_license, dcterms:license, mwo:hasAffi...
# 29  [mwo:hasRepository, owl:annotatedSource, ns2:I...
# 30  [nfdicore:Dataset, dcterms:format, mwo:hasForm...
# 31  [nfdicore:Software, mwo:hasVersion, ns3:SWO_00...
# 32  [mwo:relatedTaskArea, mwo:hasDiscipline, mwo:m...
# 33  [dcterms:description, mwo:description, dcterms...
# 34  [nfdicore:Dataset, ns2:IAO_0000119, owl:annota...
# 35  [mwo:hasCreator, mwo:hasAuthor, mwo:hasContrib...
# 36  [nfdicore:Dataset, mwo:hasRepository, dcterms:...

# %% [markdown]
# 3SimilarRelationships5X10.xlsx without "description" , 4beforeSparq5X10.xlsx with "description"
